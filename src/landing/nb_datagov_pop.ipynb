# %%
import sys
sys.path.append('..')

import pandas as pd
from utils.db_utils import write_table, read_table

# %%
POP_URL_DATA = 'https://storage.dosm.gov.my/population/population_state.parquet'
pop_df = pd.read_parquet(POP_URL_DATA)

# %%
pop_df["date"] = pd.to_datetime(pop_df["date"])

pop_df = (
    pop_df[
        (pop_df["date"] >= "2020-01-01") &
        (pop_df["sex"] == "both") &
        (pop_df["age"] == "overall") &
        (pop_df["ethnicity"] == "overall")
    ]
    .copy()
)

pop_df["population"] = (
        pop_df["population"]
        .astype(str)
        .str.replace(",", "", regex=False)
        .astype(float) * 1000
    )

pop_df = pop_df.drop(columns=["sex", "age", "ethnicity"])
pop_df.head(20)
# Out:
#           state       date  population
# 15021     Johor 2020-01-01   4009700.0
# 15420     Johor 2021-01-01   4020000.0
# 15819     Johor 2022-01-01   4028300.0
# 16218     Johor 2023-01-01   4107200.0
# 16617     Johor 2024-01-01   4184400.0
# 17016     Johor 2025-01-01   4205900.0
# 32436     Kedah 2020-01-01   2131400.0
# 32835     Kedah 2021-01-01   2151700.0
# 33234     Kedah 2022-01-01   2163100.0
# 33633     Kedah 2023-01-01   2189300.0
# 34032     Kedah 2024-01-01   2217100.0
# 34431     Kedah 2025-01-01   2228000.0
# 49851  Kelantan 2020-01-01   1792500.0
# 50250  Kelantan 2021-01-01   1812300.0
# 50649  Kelantan 2022-01-01   1830600.0
# 51048  Kelantan 2023-01-01   1859800.0
# 51447  Kelantan 2024-01-01   1887900.0
# 51846  Kelantan 2025-01-01   1907700.0
# 67266    Melaka 2020-01-01    998400.0
# 67665    Melaka 2021-01-01   1004500.0

# %%
write_table(pop_df, "sc_bronze", "datagov_population")
# Out:
# postgresql+psycopg2://postgres.eaomovixhqgdatskjgdh:Lamimi123%21%40@aws-1-ap-northeast-1.pooler.supabase.com:5432/postgres?sslmode=require
# Table sc_bronze.datagov_population written successfully.
