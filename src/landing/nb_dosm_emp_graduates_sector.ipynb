# %%
import sys
sys.path.append('..')

import pandas as pd
from utils.db_utils import write_table, read_table

# %%
df = pd.read_csv("../../data/Employed Graduates by Economic Activity.csv")

# %%
df_long = df.melt(
    id_vars="Economic Activity",
    var_name="year",
    value_name="emp_graduates"
)

# %%
df_long["emp_graduates"] = (
    df_long["emp_graduates"]
    .astype(str)
    .str.replace(",", "")
    .astype(float)
)

df_long["emp_graduates"] = df_long["emp_graduates"] * 1000

# %%
main_sectors = [
    "Agriculture",
    "Mining and Quarrying",
    "Manufacturing",
    "Construction",
    "Services"
]

manufacturing_sub = [
    "Vegetable and animal oils & fats and food processing",
    "Beverages and tobacco products",
    "Textiles, wearing apparel and leather products",
    "Wood products, furniture, paper products and printing",
    "Petroleum, chemical, rubber and plastic products",
    "Non-metallic mineral products, basic metal and fabricated metal products",
    "Electrical, electronic and optical products",
    "Transport equipment, other manufacturing and repair"
]

services_sub = [
    "Utilities",
    "Wholesale and retail trade",
    "Food & beverages and accommodation",
    "Transportation and storage",
    "Information and communication",
    "Finance and insurance",
    "Real estate and business services",
    "Other services"
]

# %%
df_long["subsector"] = df_long["Economic Activity"]

df_long["sector"] = df_long["Economic Activity"].apply(
    lambda x: "Manufacturing" if x in manufacturing_sub
    else "Services" if x in services_sub
    else x
)

# %%
df_final = df_long[["year", "sector", "subsector", "emp_graduates"]]
df_final.head(20)
# Out:
#     year                sector  \
# 0   2020           Agriculture
# 1   2020  Mining and Quarrying
# 2   2020         Manufacturing
# 3   2020         Manufacturing
# 4   2020         Manufacturing
# 5   2020         Manufacturing
# 6   2020         Manufacturing
# 7   2020         Manufacturing
# 8   2020         Manufacturing
# 9   2020         Manufacturing
# 10  2020         Manufacturing
# 11  2020          Construction
# 12  2020              Services
# 13  2020              Services
# 14  2020              Services
# 15  2020              Services
# 16  2020              Services
# 17  2020              Services
# 18  2020              Services
# 19  2020              Services
#
#                                             subsector  emp_graduates
# 0                                         Agriculture        63800.0
# 1                                Mining and Quarrying        41400.0
# 2                                       Manufacturing       579400.0
# 3   Vegetable and animal oils & fats and food proc...        87800.0
# 4                      Beverages and tobacco products         6600.0
# 5      Textiles, wearing apparel and leather products        22900.0
# 6   Wood products, furniture, paper products and p...        53100.0
# 7    Petroleum, chemical, rubber and plastic products        79300.0
# 8   Non-metallic mineral products, basic metal and...        57000.0
# 9         Electrical, electronic and optical products       211200.0
# 10  Transport equipment, other manufacturing and r...        61500.0
# 11                                       Construction       237400.0
# 12                                           Services      3131000.0
# 13                                          Utilities        41700.0
# 14                         Wholesale and retail trade       486600.0
# 15                 Food & beverages and accommodation       202100.0
# 16                         Transportation and storage       128300.0
# 17                      Information and communication       168900.0
# 18                              Finance and insurance       230900.0
# 19                  Real estate and business services       455400.0

# %%
write_table(df_final, "sc_bronze", "dosm_emp_graduates_sector ")
# Out:
# postgresql+psycopg2://postgres.eaomovixhqgdatskjgdh:Lamimi123%21%40@aws-1-ap-northeast-1.pooler.supabase.com:5432/postgres?sslmode=require
# Table sc_bronze.dosm_emp_graduates_sector  written successfully.
