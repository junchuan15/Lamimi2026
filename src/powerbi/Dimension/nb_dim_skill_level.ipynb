# %%
import sys
sys.path.append('../..')

import pandas as pd
from utils.db_utils import write_table, read_table
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 import sys
#       2 sys.path.append('../..')
# ----> 4 import pandas as pd
#       5 from utils.db_utils import write_table, read_table
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df = read_table(
    """
    select distinct(skill_level)
    from sc_bronze.dosm_jobdemand
    """
)

df.head()

# %%
df = df.sort_values("skill_level").reset_index(drop=True)
df["skill_level_id"] = ["SK" + str(i+1).zfill(3) for i in range(len(df))]
df = df[["skill_level_id"] + [c for c in df.columns if c != "skill_level_id"]]
df_final = df.rename(columns={"skill_level": "Skill_level"})
df_final

# %%
write_table(df_final, "sc_gold", "dim_skill_level")
