# %%
import sys
sys.path.append('../..')

import pandas as pd
from utils.db_utils import write_table, read_table

# %%
df = read_table(
    """
    select distinct(state) AS State
    from sc_bronze.datagov_gdp
    """
)

# %%
df = df.sort_values("state").reset_index(drop=True)
df["state_id"] = ["ST" + str(i+1).zfill(3) for i in range(len(df))]
df = df[["state_id"] + [c for c in df.columns if c != "state_id"]]
# Out:
#    state_id            state
# 0     ST001            Johor
# 1     ST002            Kedah
# 2     ST003         Kelantan
# 3     ST004     Kuala Lumpur
# 4     ST005           Labuan
# 5     ST006           Melaka
# 6     ST007  Negeri Sembilan
# 7     ST008           Pahang
# 8     ST009            Perak
# 9     ST010           Perlis
# 10    ST011     Pulau Pinang
# 11    ST012            Sabah
# 12    ST013          Sarawak
# 13    ST014         Selangor
# 14    ST015       Terengganu

# %%
df_final = df.rename(columns={"state": "State"})

# %%
write_table(df_final, "sc_gold", "dim_state")
# Out:
# postgresql+psycopg2://postgres.eaomovixhqgdatskjgdh:Lamimi123%21%40@aws-1-ap-northeast-1.pooler.supabase.com:5432/postgres?sslmode=require
# Table sc_gold.dim_state written successfully.
