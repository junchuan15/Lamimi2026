# %%
import sys
sys.path.append('../..')

import pandas as pd
from utils.db_utils import write_table, read_table

# %%
df = read_table(
    """
    select distinct date from sc_silver.forecast_underemployment
    """
)
df = df.sort_values("date").reset_index(drop=True)
df.head(20)
# Out:
#          date
# 0  2016-01-01
# 1  2016-04-01
# 2  2016-07-01
# 3  2016-10-01
# 4  2017-01-01
# 5  2017-04-01
# 6  2017-07-01
# 7  2017-10-01
# 8  2018-01-01
# 9  2018-04-01
# 10 2018-07-01
# 11 2018-10-01
# 12 2019-01-01
# 13 2019-04-01
# 14 2019-07-01
# 15 2019-10-01
# 16 2020-01-01
# 17 2020-04-01
# 18 2020-07-01
# 19 2020-10-01

# %%
df["date_id"] = ["DT" + str(i+1).zfill(3) for i in range(len(df))]
df = df[["date_id"] + [c for c in df.columns if c != "date_id"]]

# %%
write_table(df, "sc_gold", "dim_date")
# Out:
# Table sc_gold.dim_date written successfully.
