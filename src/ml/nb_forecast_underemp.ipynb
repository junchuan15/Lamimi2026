# %%
import sys
sys.path.append('..')

import pandas as pd
from utils.db_utils import write_table, read_table

# %%
df = read_table("""
write sql here               
"""
)
# Out:
#    state       date                sector  RM(million)  growth_yoy
# 0  Johor 2020-01-01           Agriculture    16856.550       2.764
# 1  Johor 2020-01-01  Mining and Quarrying      657.515     -19.080
# 2  Johor 2020-01-01         Manufacturing    38650.689      -3.674
# 3  Johor 2020-01-01          Construction     4175.525     -37.676
# 4  Johor 2020-01-01              Services    66406.166      -3.165
